# %%
from vector_utils import DenseVectors
from generate_random_vectors import get_all_words
from common_imports import *

sns.timeseries.algo.bootstrap = my_bootstrap

# %%
all_words = get_all_words()
v = DenseVectors.from_hdf('vectors/word2vec-wiki-nopos-100perc.unigr.strings.rep0',
                          row_filter=lambda x: x in all_words)

# %%
norm = np.linalg.norm(v.df.values, axis=1)
sns.distplot(norm);
norm.mean()
# Out:
# 2.3528407613216724
